# %%
### Jayesh Jain 
### PE29

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# Categories Features

from ibm_watson.natural_language_understanding_v1 import Features, CategoriesOptions

authenticator = IAMAuthenticator('wTokfhkGxmvMwUXJF3kN7XZtj0FUqjVUdi196l8j8pjj')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/21dac8cf-cdde-4791-927d-b8dec5e54d8c')

response = natural_language_understanding.analyze(
    url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
    features=Features(categories=CategoriesOptions(limit=5))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 10347,
#     "features": 1
#   },
#   "retrieved_url": "https://medium.com/svilenk/bciguide-246a9ca76fcd",
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.840051,
#       "label": "/health and fitness/disease/epilepsy"
#     },
#     {
#       "score": 0.75497,
#       "label": "/health and fitness/disorders"
#     },
#     {
#       "score": 0.665809,
#       "label": "/technology and computing/internet technology"
#     },
#     {
#       "score": 0.644254,
#       "label": "/health and fitness/disorders/mental disorder/panic and anxiety"
#     },
#     {
#       "score": 0.598532,
#       "label": "/style and fashion/body art"
#     }
#   ]
# }

# %%
# Concepts Features

from ibm_watson.natural_language_understanding_v1 import Features, ConceptsOptions
 
response = natural_language_understanding.analyze(
    url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
    features=Features(concepts=ConceptsOptions(limit=3))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 10347,
#     "features": 1
#   },
#   "retrieved_url": "https://medium.com/svilenk/bciguide-246a9ca76fcd",
#   "language": "en",
#   "concepts": [
#     {
#       "text": "Neuron",
#       "relevance": 0.985617,
#       "dbpedia_resource": "http://dbpedia.org/resource/Neuron"
#     },
#     {
#       "text": "Brain",
#       "relevance": 0.91016,
#       "dbpedia_resource": "http://dbpedia.org/resource/Brain"
#     },
#     {
#       "text": "Nervous system",
#       "relevance": 0.90425,
#       "dbpedia_resource": "http://dbpedia.org/resource/Nervous_system"
#     }
#   ]
# }

# %%
# Emotions Features
from ibm_watson.natural_language_understanding_v1 import Features, EmotionOptions

response = natural_language_understanding.analyze(
    url ="https://medium.com/svilenk/bciguide-246a9ca76fcd",
    features=Features(emotion=EmotionOptions(targets=['Brain','Neuron']))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 10347,
#     "features": 1
#   },
#   "retrieved_url": "https://medium.com/svilenk/bciguide-246a9ca76fcd",
#   "language": "en",
#   "emotion": {
#     "targets": [
#       {
#         "text": "Brain",
#         "emotion": {
#           "sadness": 0.194938,
#           "joy": 0.548856,
#           "fear": 0.173236,
#           "disgust": 0.102641,
#           "anger": 0.157512
#         }
#       },
#       {
#         "text": "Neuron",
#         "emotion": {
#           "sadness": 0.166991,
#           "joy": 0.572657,
#           "fear": 0.164208,
#           "disgust": 0.08207,
#           "anger": 0.148679
#         }
#       }
#     ],
#     "document": {
#       "emotion": {
#         "sadness": 0.537812,
#         "joy": 0.566136,
#         "fear": 0.159983,
#         "disgust": 0.093257,
#         "anger": 0.112785
#       }
#     }
#   }
# }

# %%
# Entities Features 
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions

response = natural_language_understanding.analyze(
    url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
    features=Features(entities=EntitiesOptions(sentiment=True,limit=1))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 10347,
#     "features": 1
#   },
#   "retrieved_url": "https://medium.com/svilenk/bciguide-246a9ca76fcd",
#   "language": "en",
#   "entities": [
#     {
#       "type": "Person",
#       "text": "Regina Dugan",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.950395,
#       "disambiguation": {
#         "name": "Regina_E._Dugan",
#         "dbpedia_resource": "http://dbpedia.org/resource/Regina_E._Dugan"
#       },
#       "count": 1,
#       "confidence": 0.946735
#     }
#   ]
# }

# %%
# Keywords Features
from ibm_watson.natural_language_understanding_v1 import Features, KeywordsOptions

response = natural_language_understanding.analyze(
    url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
    features=Features(keywords=KeywordsOptions(sentiment=True,emotion=True,limit=2))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 10347,
#     "features": 1
#   },
#   "retrieved_url": "https://medium.com/svilenk/bciguide-246a9ca76fcd",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "brain-computer interface",
#       "sentiment": {
#         "score": 0.875717,
#         "label": "positive"
#       },
#       "relevance": 0.651043,
#       "emotion": {
#         "sadness": 0.059572,
#         "joy": 0.450006,
#         "fear": 0.021097,
#         "disgust": 0.00691,
#         "anger": 0.064166
#       },
#       "count": 2
#     },
#     {
#       "text": "potential advantages",
#       "sentiment": {
#         "score": 0.69155,
#         "label": "positive"
#       },
#       "relevance": 0.55615,
#       "emotion": {
#         "sadness": 0.18682,
#         "joy": 0.309731,
#         "fear": 0.109136,
#         "disgust": 0.025557,
#         "anger": 0.058413
#       },
#       "count": 1
#     }
#   ]
# }

# %%
#Metadata Feature
from ibm_watson.natural_language_understanding_v1 import Features, MetadataOptions

response = natural_language_understanding.analyze(
    url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
    features=Features(metadata=MetadataOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-d55337b15b1a> in <module>
#       1 #Metadata Feature
# ----> 2 from ibm_watson.natural_language_understanding_v1 import Features, MetadataOptions
#       3
#       4 response = natural_language_understanding.analyze(
#       5     url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
#
# ImportError: cannot import name 'MetadataOptions' from 'ibm_watson.natural_language_understanding_v1' (C:\Users\admin\anaconda3\lib\site-packages\ibm_watson\natural_language_understanding_v1.py)

# %%
# Relations Features 
from ibm_watson.natural_language_understanding_v1 import Features, RelationsOptions

response = natural_language_understanding.analyze(
    url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
    features=Features(relations=RelationsOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 10347,
#     "features": 1
#   },
#   "retrieved_url": "https://medium.com/svilenk/bciguide-246a9ca76fcd",
#   "relations": [
#     {
#       "type": "agentOf",
#       "sentence": "Major players in the tech industry have announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA's Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds.",
#       "score": 0.548294,
#       "arguments": [
#         {
#           "text": "players",
#           "location": [
#             91,
#             98
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "players"
#             }
#           ]
#         },
#         {
#           "text": "announced",
#           "location": [
#             125,
#             134
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "announced"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "Here are some of today's BCI's: Scientific application aside, EEG BCI's have become fairly affordable over the years.",
#       "score": 0.455194,
#       "arguments": [
#         {
#           "text": "BCI",
#           "location": [
#             2192,
#             2195
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "BCI"
#             }
#           ]
#         },
#         {
#           "text": "EEG BCI",
#           "location": [
#             2229,
#             2236
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "EEG BCI",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "Sure, our methods have gotten more advanced, but it has essentially remained the same, as we still type out individual letters on our phones or speak.",
#       "score": 0.597715,
#       "arguments": [
#         {
#           "text": "our",
#           "location": [
#             2872,
#             2875
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "our"
#             }
#           ]
#         },
#         {
#           "text": "speak",
#           "location": [
#             2886,
#             2891
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "speak"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "And instead of describing your thoughts in words, you send them in a \"raw\" format; the abstract concept in your mind before you form it into a word.",
#       "score": 0.676794,
#       "arguments": [
#         {
#           "text": "your",
#           "location": [
#             3074,
#             3078
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "your"
#             }
#           ]
#         },
#         {
#           "text": "describing",
#           "location": [
#             3063,
#             3073
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "describing"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "partOfMany",
#       "sentence": "Last but certainly not least, the neocortex is essentially what makes us human.",
#       "score": 0.413418,
#       "arguments": [
#         {
#           "text": "neocortex",
#           "location": [
#             4228,
#             4237
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "neocortex"
#             }
#           ]
#         },
#         {
#           "text": "us",
#           "location": [
#             4264,
#             4266
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "they"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "ownerOf",
#       "sentence": "The Brain's Building Blocks The main cells of the brain are called neurons and they are cognitive highways on which electric signal travels to communicate with other neurons.",
#       "score": 0.730253,
#       "arguments": [
#         {
#           "text": "Brain",
#           "location": [
#             4354,
#             4359
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Brain",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         },
#         {
#           "text": "Building",
#           "location": [
#             4362,
#             4370
#           ],
#           "entities": [
#             {
#               "type": "Facility",
#               "text": "Building"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "Harvard professor Jeff Lichtman is quoted stating: Depressing, I know, but here's the good news\u2026 Don't Sweat the Small Stuff The good news is that we don't actually need to fully understand the brain in order to create BCI's that work.",
#       "score": 0.669276,
#       "arguments": [
#         {
#           "text": "professor",
#           "location": [
#             5784,
#             5793
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Jeff Lichtman"
#             }
#           ]
#         },
#         {
#           "text": "Harvard",
#           "location": [
#             5776,
#             5783
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Harvard"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "Harvard professor Jeff Lichtman is quoted stating: Depressing, I know, but here's the good news\u2026 Don't Sweat the Small Stuff The good news is that we don't actually need to fully understand the brain in order to create BCI's that work.",
#       "score": 0.99293,
#       "arguments": [
#         {
#           "text": "Jeff Lichtman",
#           "location": [
#             5794,
#             5807
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Jeff Lichtman"
#             }
#           ]
#         },
#         {
#           "text": "quoted",
#           "location": [
#             5811,
#             5817
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "quoted"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "locatedAt",
#       "sentence": "We don't fully understand what happens inside of A.I. neural networks either, but that didn't stop us from building an AI to beat one of the top Go players in the world.",
#       "score": 0.429027,
#       "arguments": [
#         {
#           "text": "players",
#           "location": [
#             6227,
#             6234
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "players"
#             }
#           ]
#         },
#         {
#           "text": "world",
#           "location": [
#             6242,
#             6247
#           ],
#           "entities": [
#             {
#               "type": "GeopoliticalEntity",
#               "text": "world",
#               "disambiguation": {
#                 "subtype": [
#                   "Area"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "residesIn",
#       "sentence": "Ian Stevenson, PhD has observed: It's disheartening to hear that even with exponential progress we're more than 200 years away from a full brain capture according to Stevenson, but a counter observation by Ray Kurzweil keeps our hopes alive to witness an entire brain capture in our lifetimes: \"when the Internet went from 20,000 to 80,000 nodes over a two year period during the 1980s, this progress remained hidden from the general public.",
#       "score": 0.648246,
#       "arguments": [
#         {
#           "text": "Ian Stevenson",
#           "location": [
#             8423,
#             8436
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Ian Stevenson"
#             }
#           ]
#         },
#         {
#           "text": "PhD",
#           "location": [
#             8438,
#             8441
#           ],
#           "entities": [
#             {
#               "type": "GeopoliticalEntity",
#               "text": "PhD"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "(I was actually present at the GF2045 conference when it was announced in 2013 *slight flex) This could be the wildest and possibly most drastic paradigm-shifting mechanism.",
#       "score": 0.611236,
#       "arguments": [
#         {
#           "text": "GF2045",
#           "location": [
#             9996,
#             10002
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "GF2045"
#             }
#           ]
#         },
#         {
#           "text": "conference",
#           "location": [
#             10003,
#             10013
#           ],
#           "entities": [
#             {
#               "type": "EventMeeting",
#               "text": "conference"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "Major players in the tech industry have announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA's Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds.",
#       "score": 0.596955,
#       "arguments": [
#         {
#           "text": "their",
#           "location": [
#             135,
#             140
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "users"
#             }
#           ]
#         },
#         {
#           "text": "announced",
#           "location": [
#             177,
#             186
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "announced"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "timeOf",
#       "sentence": "(I was actually present at the GF2045 conference when it was announced in 2013 *slight flex) This could be the wildest and possibly most drastic paradigm-shifting mechanism.",
#       "score": 0.636084,
#       "arguments": [
#         {
#           "text": "2013",
#           "location": [
#             10039,
#             10043
#           ],
#           "entities": [
#             {
#               "type": "Date",
#               "text": "2013"
#             }
#           ]
#         },
#         {
#           "text": "announced",
#           "location": [
#             10026,
#             10035
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "announced"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "Major players in the tech industry have announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA's Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds.",
#       "score": 0.736177,
#       "arguments": [
#         {
#           "text": "Elon Musk",
#           "location": [
#             167,
#             176
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Elon Musk"
#             }
#           ]
#         },
#         {
#           "text": "announced",
#           "location": [
#             177,
#             186
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "announced"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "Major players in the tech industry have announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA's Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds.",
#       "score": 0.945043,
#       "arguments": [
#         {
#           "text": "Facebook",
#           "location": [
#             303,
#             311
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Facebook"
#             }
#           ]
#         },
#         {
#           "text": "announced",
#           "location": [
#             312,
#             321
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "announced"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "Major players in the tech industry have announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA's Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds.",
#       "score": 0.927473,
#       "arguments": [
#         {
#           "text": "Regina Dugan",
#           "location": [
#             355,
#             367
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Regina Dugan"
#             }
#           ]
#         },
#         {
#           "text": "DARPA",
#           "location": [
#             347,
#             352
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "DARPA",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "partOfMany",
#       "sentence": "He is one of the most brilliant theoretical physicist of our time, greatly contributing to the fields of cosmology, quantum gravity, and black holes.",
#       "score": 0.563893,
#       "arguments": [
#         {
#           "text": "physicist",
#           "location": [
#             884,
#             893
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "physicist"
#             }
#           ]
#         },
#         {
#           "text": "our",
#           "location": [
#             897,
#             900
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "our"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "Due to a nasty neurodegenerative disease, he's been trapped in his own body, unable to speak or move for several decades.",
#       "score": 0.603507,
#       "arguments": [
#         {
#           "text": "body",
#           "location": [
#             1061,
#             1065
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Regina Dugan"
#             }
#           ]
#         },
#         {
#           "text": "speak",
#           "location": [
#             1077,
#             1082
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "describing"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "His mind is fully functional- he even writes books and gives lectures but unfortunately his way of communicating with the world has been reduced to typing through an mechanism embedded in his glasses using his cheek muscle movement, allowing him to type just one word per minute.",
#       "score": 0.979477,
#       "arguments": [
#         {
#           "text": "he",
#           "location": [
#             1142,
#             1144
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "physicist"
#             }
#           ]
#         },
#         {
#           "text": "writes",
#           "location": [
#             1150,
#             1156
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "writes"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "As you can see, we listen 10x faster then we write.",
#       "score": 0.981872,
#       "arguments": [
#         {
#           "text": "we",
#           "location": [
#             1805,
#             1807
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "they"
#             }
#           ]
#         },
#         {
#           "text": "write",
#           "location": [
#             1808,
#             1813
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "writes"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "language": "en"
# }

# %%
# Semantic Analysis
from ibm_watson.natural_language_understanding_v1 import Features, SemanticRolesOptions

response = natural_language_understanding.analyze(
    url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
    features=Features(semantic_roles=SemanticRolesOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 10347,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "Early 2017"
#       },
#       "sentence": "Early 2017 has been an exciting time for brain-computer interface (BCI) development.",
#       "object": {
#         "text": "an exciting time for brain-computer interface (BCI) development"
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "has been",
#         "normalized": "have be"
#       }
#     },
#     {
#       "subject": {
#         "text": "an exciting time for brain-computer interface (BCI) development"
#       },
#       "sentence": "Early 2017 has been an exciting time for brain-computer interface (BCI) development.",
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "has been",
#         "normalized": "have be"
#       }
#     },
#     {
#       "subject": {
#         "text": "Major players in the tech industry"
#       },
#       "sentence": " Major players in the tech industry have announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA\u2019s Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds.",
#       "object": {
#         "text": "announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA\u2019s Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds"
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "have",
#         "normalized": "have"
#       }
#     },
#     {
#       "subject": {
#         "text": "Major players in the tech industry"
#       },
#       "sentence": " Major players in the tech industry have announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA\u2019s Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds.",
#       "object": {
#         "text": "their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA\u2019s Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds"
#       },
#       "action": {
#         "verb": {
#           "text": "announce",
#           "tense": "past"
#         },
#         "text": "have announced",
#         "normalized": "have announce"
#       }
#     },
#     {
#       "subject": {
#         "text": "his new venture Neuralink"
#       },
#       "sentence": " Major players in the tech industry have announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA\u2019s Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds.",
#       "object": {
#         "text": "by the fear of humans being left behind by A.I.,"
#       },
#       "action": {
#         "verb": {
#           "text": "fuel",
#           "tense": "past"
#         },
#         "text": "is fueled",
#         "normalized": "be fuel"
#       }
#     },
#     {
#       "subject": {
#         "text": "by DARPA\u2019s Regina Dugan"
#       },
#       "sentence": " Major players in the tech industry have announced their involvement in the field- Elon Musk announced his new venture Neuralink, which is fueled by the fear of humans being left behind by A.I., and several weeks later Facebook announced their own efforts led by DARPA\u2019s Regina Dugan, with the goal of enabling users to type 100 words per minute using their minds.",
#       "object": {
#         "text": "their own efforts"
#       },
#       "action": {
#         "verb": {
#           "text": "lead",
#           "tense": "past"
#         },
#         "text": "led",
#         "normalized": "lead"
#       }
#     },
#     {
#       "subject": {
#         "text": "they"
#       },
#       "sentence": " How do they work and why all the hype?",
#       "object": {
#         "text": "why all the hype"
#       },
#       "action": {
#         "verb": {
#           "text": "work",
#           "tense": "present"
#         },
#         "text": "work",
#         "normalized": "work"
#       }
#     },
#     {
#       "subject": {
#         "text": "a brain-computer interface"
#       },
#       "sentence": " Simply put, a brain-computer interface is a way to connect the brain to an external device in order to send and/or receive information directly from it.",
#       "object": {
#         "text": "a way to connect the brain to an external device"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "a brain-computer interface"
#       },
#       "sentence": " Simply put, a brain-computer interface is a way to connect the brain to an external device in order to send and/or receive information directly from it.",
#       "object": {
#         "text": "the brain"
#       },
#       "action": {
#         "verb": {
#           "text": "connect",
#           "tense": "future"
#         },
#         "text": "to connect",
#         "normalized": "to connect"
#       }
#     },
#     {
#       "subject": {
#         "text": "They"
#       },
#       "sentence": " They\u2019re nothing new as research started in the early 70\u2019s, so why are they gaining so much attention lately?",
#       "object": {
#         "text": "nothing new"
#       },
#       "action": {
#         "verb": {
#           "text": "are",
#           "tense": "present"
#         },
#         "text": "re",
#         "normalized": "re"
#       }
#     },
#     {
#       "subject": {
#         "text": "research"
#       },
#       "sentence": " They\u2019re nothing new as research started in the early 70\u2019s, so why are they gaining so much attention lately?",
#       "action": {
#         "verb": {
#           "text": "start",
#           "tense": "past"
#         },
#         "text": "started",
#         "normalized": "start"
#       }
#     },
#     {
#       "subject": {
#         "text": "they gaining so much attention"
#       },
#       "sentence": " They\u2019re nothing new as research started in the early 70\u2019s, so why are they gaining so much attention lately?",
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "are",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "they"
#       },
#       "sentence": " They\u2019re nothing new as research started in the early 70\u2019s, so why are they gaining so much attention lately?",
#       "object": {
#         "text": "so much attention"
#       },
#       "action": {
#         "verb": {
#           "text": "gain",
#           "tense": "present"
#         },
#         "text": "gaining",
#         "normalized": "gain"
#       }
#     },
#     {
#       "subject": {
#         "text": "them"
#       },
#       "sentence": " What makes them so exciting?",
#       "object": {
#         "text": "so exciting"
#       },
#       "action": {
#         "verb": {
#           "text": "make",
#           "tense": "present"
#         },
#         "text": "makes",
#         "normalized": "make"
#       }
#     },
#     {
#       "subject": {
#         "text": "He"
#       },
#       "sentence": " He is one of the most brilliant theoretical physicist of our time, greatly contributing to the fields of cosmology, quantum gravity, and black holes.",
#       "object": {
#         "text": "one of the most brilliant theoretical physicist of our time, greatly contributing to the fields of cosmology, quantum gravity, and black holes"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "he"
#       },
#       "sentence": " Due to a nasty neurodegenerative disease, he\u2019s been trapped in his own body, unable to speak or move for several decades.",
#       "object": {
#         "text": "been trapped in his own body"
#       },
#       "action": {
#         "verb": {
#           "text": "has",
#           "tense": "present"
#         },
#         "text": "has",
#         "normalized": "has"
#       }
#     },
#     {
#       "subject": {
#         "text": "he"
#       },
#       "sentence": " Due to a nasty neurodegenerative disease, he\u2019s been trapped in his own body, unable to speak or move for several decades.",
#       "object": {
#         "text": "in his own body"
#       },
#       "action": {
#         "verb": {
#           "text": "trap",
#           "tense": "past"
#         },
#         "text": "s been trapped",
#         "normalized": "s be trap"
#       }
#     },
#     {
#       "subject": {
#         "text": "he"
#       },
#       "sentence": " Due to a nasty neurodegenerative disease, he\u2019s been trapped in his own body, unable to speak or move for several decades.",
#       "action": {
#         "verb": {
#           "text": "speak",
#           "tense": "future"
#         },
#         "text": "to speak or move",
#         "normalized": "to speak or move"
#       }
#     },
#     {
#       "subject": {
#         "text": "His mind"
#       },
#       "sentence": " His mind is fully functional- he even writes books and gives lectures but unfortunately his way of communicating with the world has been reduced to typing through an mechanism embedded in his glasses using his cheek muscle movement, allowing him to type just one word per minute.",
#       "object": {
#         "text": "fully functional- he"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "he"
#       },
#       "sentence": " His mind is fully functional- he even writes books and gives lectures but unfortunately his way of communicating with the world has been reduced to typing through an mechanism embedded in his glasses using his cheek muscle movement, allowing him to type just one word per minute.",
#       "object": {
#         "text": "books"
#       },
#       "action": {
#         "verb": {
#           "text": "write",
#           "tense": "present"
#         },
#         "text": "writes",
#         "normalized": "write"
#       }
#     },
#     {
#       "subject": {
#         "text": "His mind"
#       },
#       "sentence": " His mind is fully functional- he even writes books and gives lectures but unfortunately his way of communicating with the world has been reduced to typing through an mechanism embedded in his glasses using his cheek muscle movement, allowing him to type just one word per minute.",
#       "object": {
#         "text": "lectures"
#       },
#       "action": {
#         "verb": {
#           "text": "give",
#           "tense": "present"
#         },
#         "text": "gives",
#         "normalized": "give"
#       }
#     },
#     {
#       "subject": {
#         "text": "the world"
#       },
#       "sentence": " His mind is fully functional- he even writes books and gives lectures but unfortunately his way of communicating with the world has been reduced to typing through an mechanism embedded in his glasses using his cheek muscle movement, allowing him to type just one word per minute.",
#       "object": {
#         "text": "reduced to typing"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "been",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "an mechanism"
#       },
#       "sentence": " His mind is fully functional- he even writes books and gives lectures but unfortunately his way of communicating with the world has been reduced to typing through an mechanism embedded in his glasses using his cheek muscle movement, allowing him to type just one word per minute.",
#       "object": {
#         "text": "in his glasses"
#       },
#       "action": {
#         "verb": {
#           "text": "embed",
#           "tense": "past"
#         },
#         "text": "embedded",
#         "normalized": "embed"
#       }
#     },
#     {
#       "subject": {
#         "text": "his glasses"
#       },
#       "sentence": " His mind is fully functional- he even writes books and gives lectures but unfortunately his way of communicating with the world has been reduced to typing through an mechanism embedded in his glasses using his cheek muscle movement, allowing him to type just one word per minute.",
#       "object": {
#         "text": "his cheek muscle movement"
#       },
#       "action": {
#         "verb": {
#           "text": "use",
#           "tense": "present"
#         },
#         "text": "using",
#         "normalized": "use"
#       }
#     },
#     {
#       "subject": {
#         "text": "the only one"
#       },
#       "sentence": " Hawking\u2019s mind is not the only one trapped in a body that has reduced it\u2019s creative output.",
#       "object": {
#         "text": "in a body that has reduced it\u2019s creative output"
#       },
#       "action": {
#         "verb": {
#           "text": "trap",
#           "tense": "past"
#         },
#         "text": "trapped",
#         "normalized": "trap"
#       }
#     },
#     {
#       "subject": {
#         "text": "a body"
#       },
#       "sentence": " Hawking\u2019s mind is not the only one trapped in a body that has reduced it\u2019s creative output.",
#       "object": {
#         "text": "reduced it\u2019s creative output"
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "has",
#         "normalized": "have"
#       }
#     },
#     {
#       "subject": {
#         "text": "a body"
#       },
#       "sentence": " Hawking\u2019s mind is not the only one trapped in a body that has reduced it\u2019s creative output.",
#       "object": {
#         "text": "it\u2019s creative output"
#       },
#       "action": {
#         "verb": {
#           "text": "reduce",
#           "tense": "past"
#         },
#         "text": "has reduced",
#         "normalized": "have reduce"
#       }
#     },
#     {
#       "subject": {
#         "text": "it"
#       },
#       "sentence": " Hawking\u2019s mind is not the only one trapped in a body that has reduced it\u2019s creative output.",
#       "object": {
#         "text": "creative output"
#       },
#       "action": {
#         "verb": {
#           "text": "has",
#           "tense": "present"
#         },
#         "text": "s",
#         "normalized": "s"
#       }
#     },
#     {
#       "subject": {
#         "text": "We"
#       },
#       "sentence": " We\u2019re all victims of the same phenomenon.",
#       "object": {
#         "text": "all victims of the same phenomenon"
#       },
#       "action": {
#         "verb": {
#           "text": "are",
#           "tense": "present"
#         },
#         "text": "re",
#         "normalized": "re"
#       }
#     },
#     {
#       "subject": {
#         "text": "The process of getting thoughts out of our heads and into the real world"
#       },
#       "sentence": " The process of getting thoughts out of our heads and into the real world is incredibly slowed down as they first have to be converted to mechanical motion, whether it\u2019s our fingers to write or type, or our larynx to speak and pronounce.",
#       "object": {
#         "text": "incredibly slowed down"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "they first"
#       },
#       "sentence": " The process of getting thoughts out of our heads and into the real world is incredibly slowed down as they first have to be converted to mechanical motion, whether it\u2019s our fingers to write or type, or our larynx to speak and pronounce.",
#       "object": {
#         "text": "converted to mechanical motion"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "future"
#         },
#         "text": "be",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "they first"
#       },
#       "sentence": " The process of getting thoughts out of our heads and into the real world is incredibly slowed down as they first have to be converted to mechanical motion, whether it\u2019s our fingers to write or type, or our larynx to speak and pronounce.",
#       "object": {
#         "text": "to mechanical motion"
#       },
#       "action": {
#         "verb": {
#           "text": "convert",
#           "tense": "past"
#         },
#         "text": "have to be converted",
#         "normalized": "have to be convert"
#       }
#     },
#     {
#       "subject": {
#         "text": "it"
#       },
#       "sentence": " The process of getting thoughts out of our heads and into the real world is incredibly slowed down as they first have to be converted to mechanical motion, whether it\u2019s our fingers to write or type, or our larynx to speak and pronounce.",
#       "object": {
#         "text": "our fingers to write or type, or our larynx to speak and pronounce"
#       },
#       "action": {
#         "verb": {
#           "text": "has",
#           "tense": "present"
#         },
#         "text": "s",
#         "normalized": "s"
#       }
#     },
#     {
#       "subject": {
#         "text": "we"
#       },
#       "sentence": " As you can see, we listen 10x faster then we write.",
#       "object": {
#         "text": "we write"
#       },
#       "action": {
#         "verb": {
#           "text": "listen",
#           "tense": "future"
#         },
#         "text": "listen",
#         "normalized": "listen"
#       }
#     },
#     {
#       "subject": {
#         "text": "we"
#       },
#       "sentence": " As you can see, we listen 10x faster then we write.",
#       "action": {
#         "verb": {
#           "text": "write",
#           "tense": "present"
#         },
#         "text": "write",
#         "normalized": "write"
#       }
#     },
#     {
#       "subject": {
#         "text": "This"
#       },
#       "sentence": " This holds true not just for language but any form of information- images, video, and audio.",
#       "object": {
#         "text": "not just for language but any form of information- images, video, and audio"
#       },
#       "action": {
#         "verb": {
#           "text": "hold",
#           "tense": "present"
#         },
#         "text": "holds",
#         "normalized": "hold"
#       }
#     },
#     {
#       "subject": {
#         "text": "several commercial BCI\u2019s that"
#       },
#       "sentence": " Currently there are several commercial BCI\u2019s that are routinely used by thousands of people, such as deep brain stimulators that alleviate Parkinson\u2019s Disease symptoms, cochlear implants that restore hearing and and even retinal implants that restore vision.",
#       "object": {
#         "text": "routinely used by thousands of people, such as deep brain stimulators that alleviate Parkinson\u2019s Disease symptoms, cochlear implants that restore hearing and and even retinal implants that restore vision"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "are",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "by thousands of people"
#       },
#       "sentence": " Currently there are several commercial BCI\u2019s that are routinely used by thousands of people, such as deep brain stimulators that alleviate Parkinson\u2019s Disease symptoms, cochlear implants that restore hearing and and even retinal implants that restore vision.",
#       "object": {
#         "text": "several commercial BCI\u2019s"
#       },
#       "action": {
#         "verb": {
#           "text": "use",
#           "tense": "past"
#         },
#         "text": "used",
#         "normalized": "use"
#       }
#     },
#     {
#       "subject": {
#         "text": "deep brain stimulators"
#       },
#       "sentence": " Currently there are several commercial BCI\u2019s that are routinely used by thousands of people, such as deep brain stimulators that alleviate Parkinson\u2019s Disease symptoms, cochlear implants that restore hearing and and even retinal implants that restore vision.",
#       "object": {
#         "text": "Parkinson\u2019s Disease symptoms, cochlear implants that restore hearing and and even retinal implants that restore vision"
#       },
#       "action": {
#         "verb": {
#           "text": "alleviate",
#           "tense": "present"
#         },
#         "text": "alleviate",
#         "normalized": "alleviate"
#       }
#     },
#     {
#       "subject": {
#         "text": "cochlear implants"
#       },
#       "sentence": " Currently there are several commercial BCI\u2019s that are routinely used by thousands of people, such as deep brain stimulators that alleviate Parkinson\u2019s Disease symptoms, cochlear implants that restore hearing and and even retinal implants that restore vision.",
#       "object": {
#         "text": "hearing and and even retinal implants that restore vision"
#       },
#       "action": {
#         "verb": {
#           "text": "restore",
#           "tense": "present"
#         },
#         "text": "restore",
#         "normalized": "restore"
#       }
#     },
#     {
#       "subject": {
#         "text": "even retinal implants"
#       },
#       "sentence": " Currently there are several commercial BCI\u2019s that are routinely used by thousands of people, such as deep brain stimulators that alleviate Parkinson\u2019s Disease symptoms, cochlear implants that restore hearing and and even retinal implants that restore vision.",
#       "object": {
#         "text": "vision"
#       },
#       "action": {
#         "verb": {
#           "text": "restore",
#           "tense": "present"
#         },
#         "text": "restore",
#         "normalized": "restore"
#       }
#     },
#     {
#       "subject": {
#         "text": "EEG BCI\u2019s"
#       },
#       "sentence": " Scientific application aside, EEG BCI\u2019s have become fairly affordable over the years.",
#       "object": {
#         "text": "become fairly affordable"
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "have",
#         "normalized": "have"
#       }
#     },
#     {
#       "subject": {
#         "text": "EEG BCI\u2019s"
#       },
#       "sentence": " Scientific application aside, EEG BCI\u2019s have become fairly affordable over the years.",
#       "object": {
#         "text": "fairly affordable"
#       },
#       "action": {
#         "verb": {
#           "text": "become",
#           "tense": "past"
#         },
#         "text": "have become",
#         "normalized": "have become"
#       }
#     },
#     {
#       "subject": {
#         "text": "You"
#       },
#       "sentence": " You can pick up a headset at Amazon for a hundred bucks:",
#       "object": {
#         "text": "a headset"
#       },
#       "action": {
#         "verb": {
#           "text": "pick",
#           "tense": "future"
#         },
#         "text": "can pick",
#         "normalized": "can pick"
#       }
#     },
#     {
#       "subject": {
#         "text": "the exciting stuff"
#       },
#       "sentence": " Health aside, the exciting stuff is yet to come.",
#       "object": {
#         "text": "yet to come"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "some possibilities"
#       },
#       "sentence": " Here are some possibilities:",
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "are",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "some potential advantages of why you would want to connect your brain to a computer"
#       },
#       "sentence": " Here are some potential advantages of why you would want to connect your brain to a computer:",
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "are",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "you"
#       },
#       "sentence": " Here are some potential advantages of why you would want to connect your brain to a computer:",
#       "object": {
#         "text": "to connect your brain to a computer"
#       },
#       "action": {
#         "verb": {
#           "text": "want",
#           "tense": "future"
#         },
#         "text": "want",
#         "normalized": "want"
#       }
#     },
#     {
#       "subject": {
#         "text": "you"
#       },
#       "sentence": " Here are some potential advantages of why you would want to connect your brain to a computer:",
#       "object": {
#         "text": "your brain"
#       },
#       "action": {
#         "verb": {
#           "text": "connect",
#           "tense": "future"
#         },
#         "text": "would want to connect",
#         "normalized": "would want to connect"
#       }
#     },
#     {
#       "subject": {
#         "text": "Things"
#       },
#       "sentence": " Things get even more interesting when people are able to interact via BCIs, which would usher in a major paradigm shift in human communication.",
#       "object": {
#         "text": "even more interesting"
#       },
#       "action": {
#         "verb": {
#           "text": "get",
#           "tense": "present"
#         },
#         "text": "get",
#         "normalized": "get"
#       }
#     }
#   ],
#   "retrieved_url": "https://medium.com/svilenk/bciguide-246a9ca76fcd",
#   "language": "en"
# }

# %%
# Sentiment Analysis
from ibm_watson.natural_language_understanding_v1 import Features, SentimentOptions

response = natural_language_understanding.analyze(
    url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
    features=Features(sentiment=SentimentOptions(targets=['AI']))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 10347,
#     "features": 1
#   },
#   "sentiment": {
#     "targets": [
#       {
#         "text": "AI",
#         "score": 0.92847,
#         "label": "positive"
#       }
#     ],
#     "document": {
#       "score": 0.496718,
#       "label": "positive"
#     }
#   },
#   "retrieved_url": "https://medium.com/svilenk/bciguide-246a9ca76fcd",
#   "language": "en"
# }

# %%
# Syntax Analysis
from ibm_watson.natural_language_understanding_v1 import Features, SyntaxOptions, SyntaxOptionsTokens

response = natural_language_understanding.analyze(
    url='https://medium.com/svilenk/bciguide-246a9ca76fcd',
    features=Features(
      syntax=SyntaxOptions(
        sentences=True,
        tokens=SyntaxOptionsTokens(
          lemma=True,
          part_of_speech=True,
        )))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 10347,
#     "features": 1
#   },
#   "syntax": {
#     "tokens": [
#       {
#         "text": "Early",
#         "part_of_speech": "ADJ",
#         "location": [
#           0,
#           5
#         ],
#         "lemma": "early"
#       },
#       {
#         "text": "2017",
#         "part_of_speech": "NUM",
#         "location": [
#           6,
#           10
#         ]
#       },
#       {
#         "text": "has",
#         "part_of_speech": "AUX",
#         "location": [
#           11,
#           14
#         ],
#         "lemma": "have"
#       },
#       {
#         "text": "been",
#         "part_of_speech": "AUX",
#         "location": [
#           15,
#           19
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "an",
#         "part_of_speech": "DET",
#         "location": [
#           20,
#           22
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "exciting",
#         "part_of_speech": "ADJ",
#         "location": [
#           23,
#           31
#         ],
#         "lemma": "exciting"
#       },
#       {
#         "text": "time",
#         "part_of_speech": "NOUN",
#         "location": [
#           32,
#           36
#         ],
#         "lemma": "time"
#       },
#       {
#         "text": "for",
#         "part_of_speech": "ADP",
#         "location": [
#           37,
#           40
#         ],
#         "lemma": "for"
#       },
#       {
#         "text": "brain",
#         "part_of_speech": "NOUN",
#         "location": [
#           41,
#           46
#         ],
#         "lemma": "brain"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           46,
#           47
#         ]
#       },
#       {
#         "text": "computer",
#         "part_of_speech": "NOUN",
#         "location": [
#           47,
#           55
#         ],
#         "lemma": "computer"
#       },
#       {
#         "text": "interface",
#         "part_of_speech": "NOUN",
#         "location": [
#           56,
#           65
#         ],
#         "lemma": "interface"
#       },
#       {
#         "text": "(",
#         "part_of_speech": "PUNCT",
#         "location": [
#           66,
#           67
#         ]
#       },
#       {
#         "text": "BCI",
#         "part_of_speech": "PROPN",
#         "location": [
#           67,
#           70
#         ]
#       },
#       {
#         "text": ")",
#         "part_of_speech": "PUNCT",
#         "location": [
#           70,
#           71
#         ]
#       },
#       {
#         "text": "development",
#         "part_of_speech": "NOUN",
#         "location": [
#           72,
#           83
#         ],
#         "lemma": "development"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           83,
#           84
#         ]
#       },
#       {
#         "text": "Major",
#         "part_of_speech": "ADJ",
#         "location": [
#           85,
#           90
#         ],
#         "lemma": "major"
#       },
#       {
#         "text": "players",
#         "part_of_speech": "NOUN",
#         "location": [
#           91,
#           98
#         ],
#         "lemma": "player"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           99,
#           101
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           102,
#           105
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "tech",
#         "part_of_speech": "NOUN",
#         "location": [
#           106,
#           110
#         ],
#         "lemma": "tech"
#       },
#       {
#         "text": "industry",
#         "part_of_speech": "NOUN",
#         "location": [
#           111,
#           119
#         ],
#         "lemma": "industry"
#       },
#       {
#         "text": "have",
#         "part_of_speech": "AUX",
#         "location": [
#           120,
#           124
#         ],
#         "lemma": "have"
#       },
#       {
#         "text": "announced",
#         "part_of_speech": "VERB",
#         "location": [
#           125,
#           134
#         ],
#         "lemma": "announce"
#       },
#       {
#         "text": "their",
#         "part_of_speech": "PRON",
#         "location": [
#           135,
#           140
#         ],
#         "lemma": "their"
#       },
#       {
#         "text": "involvement",
#         "part_of_speech": "NOUN",
#         "location": [
#           141,
#           152
#         ],
#         "lemma": "involvement"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           153,
#           155
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           156,
#           159
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "field",
#         "part_of_speech": "NOUN",
#         "location": [
#           160,
#           165
#         ],
#         "lemma": "field"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           165,
#           166
#         ]
#       },
#       {
#         "text": "Elon",
#         "part_of_speech": "PROPN",
#         "location": [
#           167,
#           171
#         ]
#       },
#       {
#         "text": "Musk",
#         "part_of_speech": "PROPN",
#         "location": [
#           172,
#           176
#         ],
#         "lemma": "musk"
#       },
#       {
#         "text": "announced",
#         "part_of_speech": "VERB",
#         "location": [
#           177,
#           186
#         ],
#         "lemma": "announce"
#       },
#       {
#         "text": "his",
#         "part_of_speech": "PRON",
#         "location": [
#           187,
#           190
#         ],
#         "lemma": "his"
#       },
#       {
#         "text": "new",
#         "part_of_speech": "ADJ",
#         "location": [
#           191,
#           194
#         ],
#         "lemma": "new"
#       },
#       {
#         "text": "venture",
#         "part_of_speech": "NOUN",
#         "location": [
#           195,
#           202
#         ],
#         "lemma": "venture"
#       },
#       {
#         "text": "Neuralink",
#         "part_of_speech": "PROPN",
#         "location": [
#           203,
#           212
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           212,
#           213
#         ]
#       },
#       {
#         "text": "which",
#         "part_of_speech": "PRON",
#         "location": [
#           214,
#           219
#         ],
#         "lemma": "which"
#       },
#       {
#         "text": "is",
#         "part_of_speech": "AUX",
#         "location": [
#           220,
#           222
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "fueled",
#         "part_of_speech": "VERB",
#         "location": [
#           223,
#           229
#         ],
#         "lemma": "fuel"
#       },
#       {
#         "text": "by",
#         "part_of_speech": "ADP",
#         "location": [
#           230,
#           232
#         ],
#         "lemma": "by"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           233,
#           236
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "fear",
#         "part_of_speech": "NOUN",
#         "location": [
#           237,
#           241
#         ],
#         "lemma": "fear"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           242,
#           244
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "humans",
#         "part_of_speech": "NOUN",
#         "location": [
#           245,
#           251
#         ],
#         "lemma": "human"
#       },
#       {
#         "text": "being",
#         "part_of_speech": "AUX",
#         "location": [
#           252,
#           257
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "left",
#         "part_of_speech": "VERB",
#         "location": [
#           258,
#           262
#         ],
#         "lemma": "leave"
#       },
#       {
#         "text": "behind",
#         "part_of_speech": "ADP",
#         "location": [
#           263,
#           269
#         ],
#         "lemma": "behind"
#       },
#       {
#         "text": "by",
#         "part_of_speech": "ADP",
#         "location": [
#           270,
#           272
#         ],
#         "lemma": "by"
#       },
#       {
#         "text": "A.I.",
#         "part_of_speech": "PROPN",
#         "location": [
#           273,
#           277
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           277,
#           278
#         ]
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           279,
#           282
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "several",
#         "part_of_speech": "ADJ",
#         "location": [
#           283,
#           290
#         ],
#         "lemma": "several"
#       },
#       {
#         "text": "weeks",
#         "part_of_speech": "NOUN",
#         "location": [
#           291,
#           296
#         ],
#         "lemma": "week"
#       },
#       {
#         "text": "later",
#         "part_of_speech": "ADV",
#         "location": [
#           297,
#           302
#         ],
#         "lemma": "late"
#       },
#       {
#         "text": "Facebook",
#         "part_of_speech": "PROPN",
#         "location": [
#           303,
#           311
#         ]
#       },
#       {
#         "text": "announced",
#         "part_of_speech": "VERB",
#         "location": [
#           312,
#           321
#         ],
#         "lemma": "announce"
#       },
#       {
#         "text": "their",
#         "part_of_speech": "PRON",
#         "location": [
#           322,
#           327
#         ],
#         "lemma": "their"
#       },
#       {
#         "text": "own",
#         "part_of_speech": "ADJ",
#         "location": [
#           328,
#           331
#         ],
#         "lemma": "own"
#       },
#       {
#         "text": "efforts",
#         "part_of_speech": "NOUN",
#         "location": [
#           332,
#           339
#         ],
#         "lemma": "effort"
#       },
#       {
#         "text": "led",
#         "part_of_speech": "VERB",
#         "location": [
#           340,
#           343
#         ],
#         "lemma": "lead"
#       },
#       {
#         "text": "by",
#         "part_of_speech": "ADP",
#         "location": [
#           344,
#           346
#         ],
#         "lemma": "by"
#       },
#       {
#         "text": "DARPA",
#         "part_of_speech": "PROPN",
#         "location": [
#           347,
#           352
#         ]
#       },
#       {
#         "text": "\u2019s",
#         "part_of_speech": "PART",
#         "location": [
#           352,
#           354
#         ],
#         "lemma": "\u2019s"
#       },
#       {
#         "text": "Regina",
#         "part_of_speech": "PROPN",
#         "location": [
#           355,
#           361
#         ]
#       },
#       {
#         "text": "Dugan",
#         "part_of_speech": "PROPN",
#         "location": [
#           362,
#           367
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           367,
#           368
#         ]
#       },
#       {
#         "text": "with",
#         "part_of_speech": "ADP",
#         "location": [
#           369,
#           373
#         ],
#         "lemma": "with"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           374,
#           377
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "goal",
#         "part_of_speech": "NOUN",
#         "location": [
#           378,
#           382
#         ],
#         "lemma": "goal"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "SCONJ",
#         "location": [
#           383,
#           385
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "enabling",
#         "part_of_speech": "VERB",
#         "location": [
#           386,
#           394
#         ],
#         "lemma": "enable"
#       },
#       {
#         "text": "users",
#         "part_of_speech": "NOUN",
#         "location": [
#           395,
#           400
#         ],
#         "lemma": "user"
#       },
#       {
#         "text": "to",
#         "part_of_speech": "PART",
#         "location": [
#           401,
#           403
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "type",
#         "part_of_speech": "VERB",
#         "location": [
#           404,
#           408
#         ],
#         "lemma": "type"
#       },
#       {
#         "text": "100",
#         "part_of_speech": "NUM",
#         "location": [
#           409,
#           412
#         ]
#       },
#       {
#         "text": "words",
#         "part_of_speech": "NOUN",
#         "location": [
#           413,
#           418
#         ],
#         "lemma": "word"
#       },
#       {
#         "text": "per",
#         "part_of_speech": "ADP",
#         "location": [
#           419,
#           422
#         ],
#         "lemma": "per"
#       },
#       {
#         "text": "minute",
#         "part_of_speech": "NOUN",
#         "location": [
#           423,
#           429
#         ],
#         "lemma": "minute"
#       },
#       {
#         "text": "using",
#         "part_of_speech": "VERB",
#         "location": [
#           430,
#           435
#         ],
#         "lemma": "use"
#       },
#       {
#         "text": "their",
#         "part_of_speech": "PRON",
#         "location": [
#           436,
#           441
#         ],
#         "lemma": "their"
#       },
#       {
#         "text": "minds",
#         "part_of_speech": "NOUN",
#         "location": [
#           442,
#           447
#         ],
#         "lemma": "mind"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           447,
#           448
#         ]
#       },
#       {
#         "text": "But",
#         "part_of_speech": "CCONJ",
#         "location": [
#           449,
#           452
#         ],
#         "lemma": "but"
#       },
#       {
#         "text": "what",
#         "part_of_speech": "PRON",
#         "location": [
#           453,
#           457
#         ],
#         "lemma": "what"
#       },
#       {
#         "text": "exactly",
#         "part_of_speech": "ADV",
#         "location": [
#           458,
#           465
#         ],
#         "lemma": "exactly"
#       },
#       {
#         "text": "are",
#         "part_of_speech": "AUX",
#         "location": [
#           466,
#           469
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "BCIs",
#         "part_of_speech": "PROPN",
#         "location": [
#           470,
#           474
#         ]
#       },
#       {
#         "text": "?",
#         "part_of_speech": "PUNCT",
#         "location": [
#           474,
#           475
#         ]
#       },
#       {
#         "text": "What",
#         "part_of_speech": "PRON",
#         "location": [
#           476,
#           480
#         ],
#         "lemma": "what"
#       },
#       {
#         "text": "else",
#         "part_of_speech": "ADJ",
#         "location": [
#           481,
#           485
#         ]
#       },
#       {
#         "text": "could",
#         "part_of_speech": "AUX",
#         "location": [
#           486,
#           491
#         ],
#         "lemma": "can"
#       },
#       {
#         "text": "they",
#         "part_of_speech": "PRON",
#         "location": [
#           492,
#           496
#         ],
#         "lemma": "they"
#       },
#       {
#         "text": "be",
#         "part_of_speech": "AUX",
#         "location": [
#           497,
#           499
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "used",
#         "part_of_speech": "VERB",
#         "location": [
#           500,
#           504
#         ],
#         "lemma": "use"
#       },
#       {
#         "text": "for",
#         "part_of_speech": "ADP",
#         "location": [
#           505,
#           508
#         ],
#         "lemma": "for"
#       },
#       {
#         "text": "?",
#         "part_of_speech": "PUNCT",
#         "location": [
#           508,
#           509
#         ]
#       },
#       {
#         "text": "How",
#         "part_of_speech": "ADV",
#         "location": [
#           510,
#           513
#         ],
#         "lemma": "how"
#       },
#       {
#         "text": "do",
#         "part_of_speech": "AUX",
#         "location": [
#           514,
#           516
#         ],
#         "lemma": "do"
#       },
#       {
#         "text": "they",
#         "part_of_speech": "PRON",
#         "location": [
#           517,
#           521
#         ],
#         "lemma": "they"
#       },
#       {
#         "text": "work",
#         "part_of_speech": "VERB",
#         "location": [
#           522,
#           526
#         ],
#         "lemma": "work"
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           527,
#           530
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "why",
#         "part_of_speech": "ADV",
#         "location": [
#           531,
#           534
#         ],
#         "lemma": "why"
#       },
#       {
#         "text": "all",
#         "part_of_speech": "DET",
#         "location": [
#           535,
#           538
#         ],
#         "lemma": "all"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           539,
#           542
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "hype",
#         "part_of_speech": "NOUN",
#         "location": [
#           543,
#           547
#         ],
#         "lemma": "hype"
#       },
#       {
#         "text": "?",
#         "part_of_speech": "PUNCT",
#         "location": [
#           547,
#           548
#         ]
#       },
#       {
#         "text": "Simply",
#         "part_of_speech": "ADV",
#         "location": [
#           549,
#           555
#         ],
#         "lemma": "simply"
#       },
#       {
#         "text": "put",
#         "part_of_speech": "VERB",
#         "location": [
#           556,
#           559
#         ],
#         "lemma": "put"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           559,
#           560
#         ]
#       },
#       {
#         "text": "a",
#         "part_of_speech": "DET",
#         "location": [
#           561,
#           562
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "brain",
#         "part_of_speech": "NOUN",
#         "location": [
#           563,
#           568
#         ],
#         "lemma": "brain"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           568,
#           569
#         ]
#       },
#       {
#         "text": "computer",
#         "part_of_speech": "NOUN",
#         "location": [
#           569,
#           577
#         ],
#         "lemma": "computer"
#       },
#       {
#         "text": "interface",
#         "part_of_speech": "NOUN",
#         "location": [
#           578,
#           587
#         ],
#         "lemma": "interface"
#       },
#       {
#         "text": "is",
#         "part_of_speech": "AUX",
#         "location": [
#           588,
#           590
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "a",
#         "part_of_speech": "DET",
#         "location": [
#           591,
#           592
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "way",
#         "part_of_speech": "NOUN",
#         "location": [
#           593,
#           596
#         ],
#         "lemma": "way"
#       },
#       {
#         "text": "to",
#         "part_of_speech": "PART",
#         "location": [
#           597,
#           599
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "connect",
#         "part_of_speech": "VERB",
#         "location": [
#           600,
#           607
#         ],
#         "lemma": "connect"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           608,
#           611
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "brain",
#         "part_of_speech": "NOUN",
#         "location": [
#           612,
#           617
#         ],
#         "lemma": "brain"
#       },
#       {
#         "text": "to",
#         "part_of_speech": "ADP",
#         "location": [
#           618,
#           620
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "an",
#         "part_of_speech": "DET",
#         "location": [
#           621,
#           623
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "external",
#         "part_of_speech": "ADJ",
#         "location": [
#           624,
#           632
#         ],
#         "lemma": "external"
#       },
#       {
#         "text": "device",
#         "part_of_speech": "NOUN",
#         "location": [
#           633,
#           639
#         ],
#         "lemma": "device"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           640,
#           642
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "order",
#         "part_of_speech": "NOUN",
#         "location": [
#           643,
#           648
#         ],
#         "lemma": "order"
#       },
#       {
#         "text": "to",
#         "part_of_speech": "PART",
#         "location": [
#           649,
#           651
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "send",
#         "part_of_speech": "VERB",
#         "location": [
#           652,
#           656
#         ],
#         "lemma": "send"
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           657,
#           660
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "/",
#         "part_of_speech": "PUNCT",
#         "location": [
#           660,
#           661
#         ]
#       },
#       {
#         "text": "or",
#         "part_of_speech": "CCONJ",
#         "location": [
#           661,
#           663
#         ],
#         "lemma": "or"
#       },
#       {
#         "text": "receive",
#         "part_of_speech": "VERB",
#         "location": [
#           664,
#           671
#         ],
#         "lemma": "receive"
#       },
#       {
#         "text": "information",
#         "part_of_speech": "NOUN",
#         "location": [
#           672,
#           683
#         ],
#         "lemma": "information"
#       },
#       {
#         "text": "directly",
#         "part_of_speech": "ADV",
#         "location": [
#           684,
#           692
#         ],
#         "lemma": "directly"
#       },
#       {
#         "text": "from",
#         "part_of_speech": "ADP",
#         "location": [
#           693,
#           697
#         ],
#         "lemma": "from"
#       },
#       {
#         "text": "it",
#         "part_of_speech": "PRON",
#         "location": [
#           698,
#           700
#         ],
#         "lemma": "it"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           700,
#           701
#         ]
#       },
#       {
#         "text": "They",
#         "part_of_speech": "PRON",
#         "location": [
#           702,
#           706
#         ],
#         "lemma": "they"
#       },
#       {
#         "text": "\u2019re",
#         "part_of_speech": "AUX",
#         "location": [
#           706,
#           709
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "nothing",
#         "part_of_speech": "PRON",
#         "location": [
#           710,
#           717
#         ],
#         "lemma": "nothing"
#       },
#       {
#         "text": "new",
#         "part_of_speech": "ADJ",
#         "location": [
#           718,
#           721
#         ],
#         "lemma": "new"
#       },
#       {
#         "text": "as",
#         "part_of_speech": "ADP",
#         "location": [
#           722,
#           724
#         ],
#         "lemma": "as"
#       },
#       {
#         "text": "research",
#         "part_of_speech": "NOUN",
#         "location": [
#           725,
#           733
#         ],
#         "lemma": "research"
#       },
#       {
#         "text": "started",
#         "part_of_speech": "VERB",
#         "location": [
#           734,
#           741
#         ],
#         "lemma": "start"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           742,
#           744
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           745,
#           748
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "early",
#         "part_of_speech": "ADJ",
#         "location": [
#           749,
#           754
#         ],
#         "lemma": "early"
#       },
#       {
#         "text": "70\u2019s",
#         "part_of_speech": "NOUN",
#         "location": [
#           755,
#           759
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           759,
#           760
#         ]
#       },
#       {
#         "text": "so",
#         "part_of_speech": "ADV",
#         "location": [
#           761,
#           763
#         ],
#         "lemma": "so"
#       },
#       {
#         "text": "why",
#         "part_of_speech": "ADV",
#         "location": [
#           764,
#           767
#         ],
#         "lemma": "why"
#       },
#       {
#         "text": "are",
#         "part_of_speech": "AUX",
#         "location": [
#           768,
#           771
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "they",
#         "part_of_speech": "PRON",
#         "location": [
#           772,
#           776
#         ],
#         "lemma": "they"
#       },
#       {
#         "text": "gaining",
#         "part_of_speech": "VERB",
#         "location": [
#           777,
#           784
#         ],
#         "lemma": "gain"
#       },
#       {
#         "text": "so",
#         "part_of_speech": "ADV",
#         "location": [
#           785,
#           787
#         ],
#         "lemma": "so"
#       },
#       {
#         "text": "much",
#         "part_of_speech": "ADJ",
#         "location": [
#           788,
#           792
#         ],
#         "lemma": "much"
#       },
#       {
#         "text": "attention",
#         "part_of_speech": "NOUN",
#         "location": [
#           793,
#           802
#         ],
#         "lemma": "attention"
#       },
#       {
#         "text": "lately",
#         "part_of_speech": "ADV",
#         "location": [
#           803,
#           809
#         ],
#         "lemma": "lately"
#       },
#       {
#         "text": "?",
#         "part_of_speech": "PUNCT",
#         "location": [
#           809,
#           810
#         ]
#       },
#       {
#         "text": "What",
#         "part_of_speech": "PRON",
#         "location": [
#           811,
#           815
#         ],
#         "lemma": "what"
#       },
#       {
#         "text": "makes",
#         "part_of_speech": "VERB",
#         "location": [
#           816,
#           821
#         ],
#         "lemma": "make"
#       },
#       {
#         "text": "them",
#         "part_of_speech": "PRON",
#         "location": [
#           822,
#           826
#         ],
#         "lemma": "they"
#       },
#       {
#         "text": "so",
#         "part_of_speech": "ADV",
#         "location": [
#           827,
#           829
#         ],
#         "lemma": "so"
#       },
#       {
#         "text": "exciting",
#         "part_of_speech": "ADJ",
#         "location": [
#           830,
#           838
#         ],
#         "lemma": "exciting"
#       },
#       {
#         "text": "?",
#         "part_of_speech": "PUNCT",
#         "location": [
#           838,
#           839
#         ]
#       },
#       {
#         "text": "He",
#         "part_of_speech": "PRON",
#         "location": [
#           840,
#           842
#         ],
#         "lemma": "he"
#       },
#       {
#         "text": "is",
#         "part_of_speech": "AUX",
#         "location": [
#           843,
#           845
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "one",
#         "part_of_speech": "NUM",
#         "location": [
#           846,
#           849
#         ],
#         "lemma": "one"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           850,
#           852
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           853,
#           856
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "most",
#         "part_of_speech": "ADV",
#         "location": [
#           857,
#           861
#         ],
#         "lemma": "much"
#       },
#       {
#         "text": "brilliant",
#         "part_of_speech": "ADJ",
#         "location": [
#           862,
#           871
#         ],
#         "lemma": "brilliant"
#       },
#       {
#         "text": "theoretical",
#         "part_of_speech": "ADJ",
#         "location": [
#           872,
#           883
#         ],
#         "lemma": "theoretic"
#       },
#       {
#         "text": "physicist",
#         "part_of_speech": "NOUN",
#         "location": [
#           884,
#           893
#         ],
#         "lemma": "physicist"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           894,
#           896
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "our",
#         "part_of_speech": "PRON",
#         "location": [
#           897,
#           900
#         ],
#         "lemma": "our"
#       },
#       {
#         "text": "time",
#         "part_of_speech": "NOUN",
#         "location": [
#           901,
#           905
#         ],
#         "lemma": "time"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           905,
#           906
#         ]
#       },
#       {
#         "text": "greatly",
#         "part_of_speech": "ADV",
#         "location": [
#           907,
#           914
#         ],
#         "lemma": "greatly"
#       },
#       {
#         "text": "contributing",
#         "part_of_speech": "VERB",
#         "location": [
#           915,
#           927
#         ],
#         "lemma": "contribute"
#       },
#       {
#         "text": "to",
#         "part_of_speech": "ADP",
#         "location": [
#           928,
#           930
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           931,
#           934
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "fields",
#         "part_of_speech": "NOUN",
#         "location": [
#           935,
#           941
#         ],
#         "lemma": "field"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           942,
#           944
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "cosmology",
#         "part_of_speech": "NOUN",
#         "location": [
#           945,
#           954
#         ],
#         "lemma": "cosmology"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           954,
#           955
#         ]
#       },
#       {
#         "text": "quantum",
#         "part_of_speech": "NOUN",
#         "location": [
#           956,
#           963
#         ],
#         "lemma": "quantum"
#       },
#       {
#         "text": "gravity",
#         "part_of_speech": "NOUN",
#         "location": [
#           964,
#           971
#         ],
#         "lemma": "gravity"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           971,
#           972
#         ]
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           973,
#           976
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "black",
#         "part_of_speech": "ADJ",
#         "location": [
#           977,
#           982
#         ],
#         "lemma": "black"
#       },
#       {
#         "text": "holes",
#         "part_of_speech": "NOUN",
#         "location": [
#           983,
#           988
#         ],
#         "lemma": "hole"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           988,
#           989
#         ]
#       },
#       {
#         "text": "Due",
#         "part_of_speech": "ADP",
#         "location": [
#           990,
#           993
#         ]
#       },
#       {
#         "text": "to",
#         "part_of_speech": "ADP",
#         "location": [
#           994,
#           996
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "a",
#         "part_of_speech": "DET",
#         "location": [
#           997,
#           998
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "nasty",
#         "part_of_speech": "ADJ",
#         "location": [
#           999,
#           1004
#         ],
#         "lemma": "nasty"
#       },
#       {
#         "text": "neurodegenerative",
#         "part_of_speech": "ADJ",
#         "location": [
#           1005,
#           1022
#         ]
#       },
#       {
#         "text": "disease",
#         "part_of_speech": "NOUN",
#         "location": [
#           1023,
#           1030
#         ],
#         "lemma": "disease"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1030,
#           1031
#         ]
#       },
#       {
#         "text": "he",
#         "part_of_speech": "PRON",
#         "location": [
#           1032,
#           1034
#         ],
#         "lemma": "he"
#       },
#       {
#         "text": "\u2019s",
#         "part_of_speech": "AUX",
#         "location": [
#           1034,
#           1036
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "been",
#         "part_of_speech": "AUX",
#         "location": [
#           1037,
#           1041
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "trapped",
#         "part_of_speech": "VERB",
#         "location": [
#           1042,
#           1049
#         ],
#         "lemma": "trap"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           1050,
#           1052
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "his",
#         "part_of_speech": "PRON",
#         "location": [
#           1053,
#           1056
#         ],
#         "lemma": "his"
#       },
#       {
#         "text": "own",
#         "part_of_speech": "ADJ",
#         "location": [
#           1057,
#           1060
#         ],
#         "lemma": "own"
#       },
#       {
#         "text": "body",
#         "part_of_speech": "NOUN",
#         "location": [
#           1061,
#           1065
#         ],
#         "lemma": "body"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1065,
#           1066
#         ]
#       },
#       {
#         "text": "unable",
#         "part_of_speech": "ADJ",
#         "location": [
#           1067,
#           1073
#         ],
#         "lemma": "unable"
#       },
#       {
#         "text": "to",
#         "part_of_speech": "PART",
#         "location": [
#           1074,
#           1076
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "speak",
#         "part_of_speech": "VERB",
#         "location": [
#           1077,
#           1082
#         ],
#         "lemma": "speak"
#       },
#       {
#         "text": "or",
#         "part_of_speech": "CCONJ",
#         "location": [
#           1083,
#           1085
#         ],
#         "lemma": "or"
#       },
#       {
#         "text": "move",
#         "part_of_speech": "NOUN",
#         "location": [
#           1086,
#           1090
#         ],
#         "lemma": "move"
#       },
#       {
#         "text": "for",
#         "part_of_speech": "ADP",
#         "location": [
#           1091,
#           1094
#         ],
#         "lemma": "for"
#       },
#       {
#         "text": "several",
#         "part_of_speech": "ADJ",
#         "location": [
#           1095,
#           1102
#         ],
#         "lemma": "several"
#       },
#       {
#         "text": "decades",
#         "part_of_speech": "NOUN",
#         "location": [
#           1103,
#           1110
#         ],
#         "lemma": "decade"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1110,
#           1111
#         ]
#       },
#       {
#         "text": "His",
#         "part_of_speech": "PRON",
#         "location": [
#           1112,
#           1115
#         ],
#         "lemma": "his"
#       },
#       {
#         "text": "mind",
#         "part_of_speech": "NOUN",
#         "location": [
#           1116,
#           1120
#         ],
#         "lemma": "mind"
#       },
#       {
#         "text": "is",
#         "part_of_speech": "AUX",
#         "location": [
#           1121,
#           1123
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "fully",
#         "part_of_speech": "ADV",
#         "location": [
#           1124,
#           1129
#         ],
#         "lemma": "fully"
#       },
#       {
#         "text": "functional",
#         "part_of_speech": "ADJ",
#         "location": [
#           1130,
#           1140
#         ],
#         "lemma": "functional"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1140,
#           1141
#         ]
#       },
#       {
#         "text": "he",
#         "part_of_speech": "PRON",
#         "location": [
#           1142,
#           1144
#         ],
#         "lemma": "he"
#       },
#       {
#         "text": "even",
#         "part_of_speech": "ADV",
#         "location": [
#           1145,
#           1149
#         ],
#         "lemma": "even"
#       },
#       {
#         "text": "writes",
#         "part_of_speech": "VERB",
#         "location": [
#           1150,
#           1156
#         ],
#         "lemma": "write"
#       },
#       {
#         "text": "books",
#         "part_of_speech": "NOUN",
#         "location": [
#           1157,
#           1162
#         ],
#         "lemma": "book"
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           1163,
#           1166
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "gives",
#         "part_of_speech": "VERB",
#         "location": [
#           1167,
#           1172
#         ],
#         "lemma": "give"
#       },
#       {
#         "text": "lectures",
#         "part_of_speech": "NOUN",
#         "location": [
#           1173,
#           1181
#         ],
#         "lemma": "lecture"
#       },
#       {
#         "text": "but",
#         "part_of_speech": "CCONJ",
#         "location": [
#           1182,
#           1185
#         ],
#         "lemma": "but"
#       },
#       {
#         "text": "unfortunately",
#         "part_of_speech": "ADV",
#         "location": [
#           1186,
#           1199
#         ],
#         "lemma": "unfortunately"
#       },
#       {
#         "text": "his",
#         "part_of_speech": "PRON",
#         "location": [
#           1200,
#           1203
#         ],
#         "lemma": "his"
#       },
#       {
#         "text": "way",
#         "part_of_speech": "NOUN",
#         "location": [
#           1204,
#           1207
#         ],
#         "lemma": "way"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "SCONJ",
#         "location": [
#           1208,
#           1210
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "communicating",
#         "part_of_speech": "VERB",
#         "location": [
#           1211,
#           1224
#         ],
#         "lemma": "communicate"
#       },
#       {
#         "text": "with",
#         "part_of_speech": "ADP",
#         "location": [
#           1225,
#           1229
#         ],
#         "lemma": "with"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1230,
#           1233
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "world",
#         "part_of_speech": "NOUN",
#         "location": [
#           1234,
#           1239
#         ],
#         "lemma": "world"
#       },
#       {
#         "text": "has",
#         "part_of_speech": "AUX",
#         "location": [
#           1240,
#           1243
#         ],
#         "lemma": "have"
#       },
#       {
#         "text": "been",
#         "part_of_speech": "AUX",
#         "location": [
#           1244,
#           1248
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "reduced",
#         "part_of_speech": "VERB",
#         "location": [
#           1249,
#           1256
#         ],
#         "lemma": "reduce"
#       },
#       {
#         "text": "to",
#         "part_of_speech": "SCONJ",
#         "location": [
#           1257,
#           1259
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "typing",
#         "part_of_speech": "VERB",
#         "location": [
#           1260,
#           1266
#         ],
#         "lemma": "type"
#       },
#       {
#         "text": "through",
#         "part_of_speech": "ADP",
#         "location": [
#           1267,
#           1274
#         ],
#         "lemma": "through"
#       },
#       {
#         "text": "an",
#         "part_of_speech": "DET",
#         "location": [
#           1275,
#           1277
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "mechanism",
#         "part_of_speech": "NOUN",
#         "location": [
#           1278,
#           1287
#         ],
#         "lemma": "mechanism"
#       },
#       {
#         "text": "embedded",
#         "part_of_speech": "VERB",
#         "location": [
#           1288,
#           1296
#         ],
#         "lemma": "embed"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           1297,
#           1299
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "his",
#         "part_of_speech": "PRON",
#         "location": [
#           1300,
#           1303
#         ],
#         "lemma": "his"
#       },
#       {
#         "text": "glasses",
#         "part_of_speech": "NOUN",
#         "location": [
#           1304,
#           1311
#         ],
#         "lemma": "glass"
#       },
#       {
#         "text": "using",
#         "part_of_speech": "VERB",
#         "location": [
#           1312,
#           1317
#         ],
#         "lemma": "use"
#       },
#       {
#         "text": "his",
#         "part_of_speech": "PRON",
#         "location": [
#           1318,
#           1321
#         ],
#         "lemma": "his"
#       },
#       {
#         "text": "cheek",
#         "part_of_speech": "NOUN",
#         "location": [
#           1322,
#           1327
#         ],
#         "lemma": "cheek"
#       },
#       {
#         "text": "muscle",
#         "part_of_speech": "NOUN",
#         "location": [
#           1328,
#           1334
#         ],
#         "lemma": "muscle"
#       },
#       {
#         "text": "movement",
#         "part_of_speech": "NOUN",
#         "location": [
#           1335,
#           1343
#         ],
#         "lemma": "movement"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1343,
#           1344
#         ]
#       },
#       {
#         "text": "allowing",
#         "part_of_speech": "VERB",
#         "location": [
#           1345,
#           1353
#         ],
#         "lemma": "allow"
#       },
#       {
#         "text": "him",
#         "part_of_speech": "PRON",
#         "location": [
#           1354,
#           1357
#         ],
#         "lemma": "he"
#       },
#       {
#         "text": "to",
#         "part_of_speech": "PART",
#         "location": [
#           1358,
#           1360
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "type",
#         "part_of_speech": "VERB",
#         "location": [
#           1361,
#           1365
#         ],
#         "lemma": "type"
#       },
#       {
#         "text": "just",
#         "part_of_speech": "ADV",
#         "location": [
#           1366,
#           1370
#         ],
#         "lemma": "just"
#       },
#       {
#         "text": "one",
#         "part_of_speech": "NUM",
#         "location": [
#           1371,
#           1374
#         ],
#         "lemma": "one"
#       },
#       {
#         "text": "word",
#         "part_of_speech": "NOUN",
#         "location": [
#           1375,
#           1379
#         ],
#         "lemma": "word"
#       },
#       {
#         "text": "per",
#         "part_of_speech": "ADP",
#         "location": [
#           1380,
#           1383
#         ],
#         "lemma": "per"
#       },
#       {
#         "text": "minute",
#         "part_of_speech": "NOUN",
#         "location": [
#           1384,
#           1390
#         ],
#         "lemma": "minute"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1390,
#           1391
#         ]
#       },
#       {
#         "text": "Hawking",
#         "part_of_speech": "VERB",
#         "location": [
#           1392,
#           1399
#         ],
#         "lemma": "hawk"
#       },
#       {
#         "text": "\u2019s",
#         "part_of_speech": "PART",
#         "location": [
#           1399,
#           1401
#         ],
#         "lemma": "\u2019s"
#       },
#       {
#         "text": "mind",
#         "part_of_speech": "NOUN",
#         "location": [
#           1402,
#           1406
#         ],
#         "lemma": "mind"
#       },
#       {
#         "text": "is",
#         "part_of_speech": "AUX",
#         "location": [
#           1407,
#           1409
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "not",
#         "part_of_speech": "PART",
#         "location": [
#           1410,
#           1413
#         ],
#         "lemma": "not"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1414,
#           1417
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "only",
#         "part_of_speech": "ADJ",
#         "location": [
#           1418,
#           1422
#         ],
#         "lemma": "only"
#       },
#       {
#         "text": "one",
#         "part_of_speech": "NOUN",
#         "location": [
#           1423,
#           1426
#         ],
#         "lemma": "one"
#       },
#       {
#         "text": "trapped",
#         "part_of_speech": "VERB",
#         "location": [
#           1427,
#           1434
#         ],
#         "lemma": "trap"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           1435,
#           1437
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "a",
#         "part_of_speech": "DET",
#         "location": [
#           1438,
#           1439
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "body",
#         "part_of_speech": "NOUN",
#         "location": [
#           1440,
#           1444
#         ],
#         "lemma": "body"
#       },
#       {
#         "text": "that",
#         "part_of_speech": "PRON",
#         "location": [
#           1445,
#           1449
#         ],
#         "lemma": "that"
#       },
#       {
#         "text": "has",
#         "part_of_speech": "AUX",
#         "location": [
#           1450,
#           1453
#         ],
#         "lemma": "have"
#       },
#       {
#         "text": "reduced",
#         "part_of_speech": "VERB",
#         "location": [
#           1454,
#           1461
#         ],
#         "lemma": "reduce"
#       },
#       {
#         "text": "it",
#         "part_of_speech": "PRON",
#         "location": [
#           1462,
#           1464
#         ],
#         "lemma": "it"
#       },
#       {
#         "text": "\u2019s",
#         "part_of_speech": "AUX",
#         "location": [
#           1464,
#           1466
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "creative",
#         "part_of_speech": "ADJ",
#         "location": [
#           1467,
#           1475
#         ],
#         "lemma": "creative"
#       },
#       {
#         "text": "output",
#         "part_of_speech": "NOUN",
#         "location": [
#           1476,
#           1482
#         ],
#         "lemma": "output"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1482,
#           1483
#         ]
#       },
#       {
#         "text": "We",
#         "part_of_speech": "PRON",
#         "location": [
#           1484,
#           1486
#         ],
#         "lemma": "we"
#       },
#       {
#         "text": "\u2019re",
#         "part_of_speech": "AUX",
#         "location": [
#           1486,
#           1489
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "all",
#         "part_of_speech": "DET",
#         "location": [
#           1490,
#           1493
#         ],
#         "lemma": "all"
#       },
#       {
#         "text": "victims",
#         "part_of_speech": "NOUN",
#         "location": [
#           1494,
#           1501
#         ],
#         "lemma": "victim"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           1502,
#           1504
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1505,
#           1508
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "same",
#         "part_of_speech": "ADJ",
#         "location": [
#           1509,
#           1513
#         ],
#         "lemma": "same"
#       },
#       {
#         "text": "phenomenon",
#         "part_of_speech": "NOUN",
#         "location": [
#           1514,
#           1524
#         ],
#         "lemma": "phenomenon"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1524,
#           1525
#         ]
#       },
#       {
#         "text": "The",
#         "part_of_speech": "DET",
#         "location": [
#           1526,
#           1529
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "process",
#         "part_of_speech": "NOUN",
#         "location": [
#           1530,
#           1537
#         ],
# ...
#         "location": [
#           3048,
#           3196
#         ]
#       },
#       {
#         "text": "Multi-dimensional concepts that would otherwise take thousands of words to explain, could all the sudden become intuitive to others in seconds.",
#         "location": [
#           3197,
#           3340
#         ]
#       },
#       {
#         "text": "This all sounds great, but where do we even start?",
#         "location": [
#           3341,
#           3391
#         ]
#       },
#       {
#         "text": "It\u2019s All in Your Head",
#         "location": [
#           3392,
#           3413
#         ]
#       },
#       {
#         "text": "In order to understand how to connect to the brain, we need to cover some fundamental neurophysiology principles\u2026",
#         "location": [
#           3414,
#           3527
#         ]
#       },
#       {
#         "text": "Let\u2019s start with the big picture first-",
#         "location": [
#           3528,
#           3567
#         ]
#       },
#       {
#         "text": "This is a gross oversimplification of the configuration of the human brain, but you can think of it in 3 distinct layers that evolved over time:",
#         "location": [
#           3568,
#           3712
#         ]
#       },
#       {
#         "text": "The first and oldest layer that sits at the base.",
#         "location": [
#           3713,
#           3762
#         ]
#       },
#       {
#         "text": "As the name suggests, it evolved before homo sapiens and is shared by all reptiles and mammals.",
#         "location": [
#           3763,
#           3858
#         ]
#       },
#       {
#         "text": "It is responsible for basic involuntary functions like heart rate, breathing, blinking, etc as well as survival instincts such as fear and aggression.",
#         "location": [
#           3859,
#           4009
#         ]
#       },
#       {
#         "text": "Evolved on top of the reptilian brain houses the limbic system and is responsible for memories and emotions.",
#         "location": [
#           4010,
#           4118
#         ]
#       },
#       {
#         "text": "It governs the fight or flight reflex, along with desire for food and sex.",
#         "location": [
#           4119,
#           4193
#         ]
#       },
#       {
#         "text": "Last but certainly not least, the neocortex is essentially what makes us human.",
#         "location": [
#           4194,
#           4273
#         ]
#       },
#       {
#         "text": "It\u2019s responsible for thinking, reasoning, planning and executive functions.",
#         "location": [
#           4274,
#           4349
#         ]
#       },
#       {
#         "text": "The Brain\u2019s Building Blocks",
#         "location": [
#           4350,
#           4377
#         ]
#       },
#       {
#         "text": "The main cells of the brain are called neurons and they are cognitive highways on which electric signal travels to communicate with other neurons.",
#         "location": [
#           4378,
#           4524
#         ]
#       },
#       {
#         "text": "There\u2019s about 80 billion of them and they all connect to each other, forming a massive network of 100 trillion synapses (the connection between neurons.",
#         "location": [
#           4525,
#           4677
#         ]
#       },
#       {
#         "text": ")",
#         "location": [
#           4677,
#           4678
#         ]
#       },
#       {
#         "text": "Neurons have to two sets of cables to to speak:",
#         "location": [
#           4679,
#           4726
#         ]
#       },
#       {
#         "text": "How neurons \u201ctalk\u201d to each other",
#         "location": [
#           4727,
#           4759
#         ]
#       },
#       {
#         "text": "When the axons of one neuron releases neurotransmitters to the dendrites of another, that chemical reaction changes the receiving neuron\u2019s charge to positive, causing it to fire an electric signal which is called an \u201caction potential\u201d",
#         "location": [
#           4760,
#           4994
#         ]
#       },
#       {
#         "text": "These action potentials are binary- it\u2019s either on or off with no middle state and could travel anywhere between 1 to 100 meters per second depending the axon layering of myelin sheath, which not only coats and protects axons, but speeds up the electric impulse.",
#         "location": [
#           4995,
#           5257
#         ]
#       },
#       {
#         "text": "Ok, now that we covered some basic neuroscience premises, and got the dull part out of the way, let\u2019s move on\u2026",
#         "location": [
#           5258,
#           5368
#         ]
#       },
#       {
#         "text": "As if the sheer number of neurons and synaptic connections is not challenging enough there\u2019s another layer of complexity- neuroplasticity.",
#         "location": [
#           5369,
#           5507
#         ]
#       },
#       {
#         "text": "Neurons are always rewiring themselves to other neurons and even changing their structure and functionality based on our life experiences in order to optimize us to our environment.",
#         "location": [
#           5508,
#           5689
#         ]
#       },
#       {
#         "text": "By this point it should be apparent that we understand extremely little of the brain.",
#         "location": [
#           5690,
#           5775
#         ]
#       },
#       {
#         "text": "Harvard professor Jeff Lichtman is quoted stating:",
#         "location": [
#           5776,
#           5826
#         ]
#       },
#       {
#         "text": "Depressing, I know, but here\u2019s the good news\u2026",
#         "location": [
#           5827,
#           5872
#         ]
#       },
#       {
#         "text": "Don\u2019t Sweat the Small Stuff",
#         "location": [
#           5873,
#           5900
#         ]
#       },
#       {
#         "text": "The good news is that we don\u2019t actually need to fully understand the brain in order to create BCI\u2019s that work.",
#         "location": [
#           5901,
#           6011
#         ]
#       },
#       {
#         "text": "We just need a really good grasp of it\u2019s high level functionality.",
#         "location": [
#           6012,
#           6078
#         ]
#       },
#       {
#         "text": "We don\u2019t fully understand what happens inside of A.I. neural networks either, but that didn\u2019t stop us from building an AI to beat one of the top Go players in the world.",
#         "location": [
#           6079,
#           6248
#         ]
#       },
#       {
#         "text": "Our next logical step towards achieving the potential wonders of BCI\u2019s is to scale up our neuron capturing capabilities as we\u2019ve already made significant progress in that area.",
#         "location": [
#           6249,
#           6425
#         ]
#       },
#       {
#         "text": "When it comes to capturing neural activity, there are two promising methods",
#         "location": [
#           6426,
#           6501
#         ]
#       },
#       {
#         "text": "When it comes to recording brain activity here are the 6 major devices.",
#         "location": [
#           6502,
#           6573
#         ]
#       },
#       {
#         "text": "We\u2019ll analyze them by the following attributes:",
#         "location": [
#           6574,
#           6621
#         ]
#       },
#       {
#         "text": "In order to have useful BCIs, we need an approach that ranks highly in both of those ares.",
#         "location": [
#           6622,
#           6712
#         ]
#       },
#       {
#         "text": "Let\u2019s start with the non-invasive methods which don\u2019t require surgery\u2026",
#         "location": [
#           6713,
#           6783
#         ]
#       },
#       {
#         "text": "fMRI",
#         "location": [
#           6784,
#           6788
#         ]
#       },
#       {
#         "text": "(functional magnetic resonance imagine)",
#         "location": [
#           6789,
#           6828
#         ]
#       },
#       {
#         "text": "-Neuroimaging procedure that captures neural activity by tracking changes in blood flow, which due to its nature is delayed by several seconds, not providing real-time information.",
#         "location": [
#           6829,
#           7009
#         ]
#       },
#       {
#         "text": "It also requires strong magnetic activity.",
#         "location": [
#           7010,
#           7052
#         ]
#       },
#       {
#         "text": "Scale: high (shows info across the brain)",
#         "location": [
#           7053,
#           7094
#         ]
#       },
#       {
#         "text": "Resolution: medium-low spatial, very low temporal",
#         "location": [
#           7095,
#           7144
#         ]
#       },
#       {
#         "text": "(electroencephalography)",
#         "location": [
#           7145,
#           7169
#         ]
#       },
#       {
#         "text": "One of the most ubiquitous method due to low cost and easy deployment that uses external electrodes to track electric activity.",
#         "location": [
#           7170,
#           7297
#         ]
#       },
#       {
#         "text": "Scale: High",
#         "location": [
#           7298,
#           7309
#         ]
#       },
#       {
#         "text": "Resolution: low spatial, medium-high temporal",
#         "location": [
#           7310,
#           7355
#         ]
#       },
#       {
#         "text": "Now, let\u2019s move to the further end of the invasiveness spectrum that require some form of surgery\u2026",
#         "location": [
#           7356,
#           7454
#         ]
#       },
#       {
#         "text": "(electrocarticography)",
#         "location": [
#           7455,
#           7477
#         ]
#       },
#       {
#         "text": "Similar to EEG, except it\u2019s deployed below the scalp, on surface of the brain.",
#         "location": [
#           7478,
#           7556
#         ]
#       },
#       {
#         "text": "Scale: High",
#         "location": [
#           7557,
#           7568
#         ]
#       },
#       {
#         "text": "Resolution: low-spatial, high temporal",
#         "location": [
#           7569,
#           7607
#         ]
#       },
#       {
#         "text": "(Local Field Potential)",
#         "location": [
#           7608,
#           7631
#         ]
#       },
#       {
#         "text": "Similar to ECoG except it\u2019s pinned on the actual cortex of the brain using micro electrodes.",
#         "location": [
#           7632,
#           7724
#         ]
#       },
#       {
#         "text": "Scale: low",
#         "location": [
#           7725,
#           7735
#         ]
#       },
#       {
#         "text": "Resolution: medium-low spatial, high temporal",
#         "location": [
#           7736,
#           7781
#         ]
#       },
#       {
#         "text": "Similar to LFP, it uses a neural electrodes to capture single neuron activity.",
#         "location": [
#           7782,
#           7860
#         ]
#       },
#       {
#         "text": "Scale: Extremely small",
#         "location": [
#           7861,
#           7883
#         ]
#       },
#       {
#         "text": "Resolution: Extremely high",
#         "location": [
#           7884,
#           7910
#         ]
#       },
#       {
#         "text": "A suction cup that clamps a neuron and can record its activity with a super-high resolution with very little noise.",
#         "location": [
#           7911,
#           8026
#         ]
#       },
#       {
#         "text": "What makes this technique unique is the fact that the clamp can actually stimulate the neuron as well with electric current.",
#         "location": [
#           8027,
#           8151
#         ]
#       },
#       {
#         "text": "Scale: Extremely small",
#         "location": [
#           8152,
#           8174
#         ]
#       },
#       {
#         "text": "Resolution: Extremely high",
#         "location": [
#           8175,
#           8201
#         ]
#       },
#       {
#         "text": "This is the only intracellular technique that actually penetrates the neuron to record individual electric activity.",
#         "location": [
#           8202,
#           8318
#         ]
#       },
#       {
#         "text": "This however will never scale as it kills the neuron.",
#         "location": [
#           8319,
#           8372
#         ]
#       },
#       {
#         "text": "Scale: impossible",
#         "location": [
#           8373,
#           8390
#         ]
#       },
#       {
#         "text": "Resolution: As high as it gets.",
#         "location": [
#           8391,
#           8422
#         ]
#       },
#       {
#         "text": "Ian Stevenson, PhD has observed:",
#         "location": [
#           8423,
#           8455
#         ]
#       },
#       {
#         "text": "It\u2019s disheartening to hear that even with exponential progress we\u2019re more than 200 years away from a full brain capture according to Stevenson, but a counter observation by Ray Kurzweil keeps our hopes alive to witness an entire brain capture in our lifetimes:",
#         "location": [
#           8456,
#           8716
#         ]
#       },
#       {
#         "text": "\u201cwhen the Internet went from 20,000 to 80,000 nodes over a two year period during the 1980s, this progress remained hidden from the general public.",
#         "location": [
#           8717,
#           8864
#         ]
#       },
#       {
#         "text": "A decade later, when it went from 20 million to 80 million nodes in the same amount of time, the impact was rather conspicuous.",
#         "location": [
#           8865,
#           8992
#         ]
#       },
#       {
#         "text": "\u201d",
#         "location": [
#           8992,
#           8993
#         ]
#       },
#       {
#         "text": "We\u2019ve covered a wide breadth of neuroimaging methods, but techniques by themselves are not enough- we need sufficient advancements in the instruments we use in order to increase overall bandwidth, less invasively.",
#         "location": [
#           8994,
#           9207
#         ]
#       },
#       {
#         "text": "Here are the most promising instruments that could take us to where we want to be\u2026",
#         "location": [
#           9208,
#           9290
#         ]
#       },
#       {
#         "text": "A silk film embedded with probes that wraps around the crevices of the brain\u2019s surface.",
#         "location": [
#           9291,
#           9378
#         ]
#       },
#       {
#         "text": "This electronic tattoo has the potential to be applied to organs like the heart and brain.",
#         "location": [
#           9379,
#           9469
#         ]
#       },
#       {
#         "text": "Soft mesh that\u2019s so flexible that it could be injected through a needle and then unfold and wrap around the brain.",
#         "location": [
#           9470,
#           9584
#         ]
#       },
#       {
#         "text": "A magnetic coil that stimulates the brain externally via magnetic waves.",
#         "location": [
#           9585,
#           9657
#         ]
#       },
#       {
#         "text": "As the name implies, tiny 100\u00b5m silicon sensors are sprinkled all over the brain to capture neural activity and transmit it wirelessly through your skull.",
#         "location": [
#           9658,
#           9812
#         ]
#       },
#       {
#         "text": "It is highly promising as it could scale extremely high and cover the entirety of the brain, while providing very high spatial and temporal resolution.",
#         "location": [
#           9813,
#           9964
#         ]
#       },
#       {
#         "text": "(I was actually present at the GF2045 conference when it was announced in 2013 *slight flex)",
#         "location": [
#           9965,
#           10057
#         ]
#       },
#       {
#         "text": "This could be the wildest and possibly most drastic paradigm-shifting mechanism.",
#         "location": [
#           10058,
#           10138
#         ]
#       },
#       {
#         "text": "It involves injecting a virus into the brain which delivers light sensitive probing molecules which can be controlled through light.",
#         "location": [
#           10139,
#           10271
#         ]
#       },
#       {
#         "text": "Optogenetics has perhaps the highest potential for resolution and scaling.",
#         "location": [
#           10272,
#           10346
#         ]
#       }
#     ]
#   },
#   "retrieved_url": "https://medium.com/svilenk/bciguide-246a9ca76fcd",
#   "language": "en"
# }
