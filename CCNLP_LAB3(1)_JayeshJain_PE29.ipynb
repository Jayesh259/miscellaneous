# %%
### Jayesh Jain 
### PE29

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# Categories Features

from ibm_watson.natural_language_understanding_v1 import Features, CategoriesOptions

authenticator = IAMAuthenticator('c7oM7ploBXw0Nxy2AR9HdcS0TGVS4bvhCPzRw1pSbS7x')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/9a80427e-a0cd-4be2-9a35-9a7c29a20322')

response = natural_language_understanding.analyze(
    url='www.ibm.com',
    features=Features(categories=CategoriesOptions(limit=3))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 982,
#     "features": 1
#   },
#   "retrieved_url": "https://www.ibm.com/uk-en",
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.854567,
#       "label": "/business and industrial/business news"
#     },
#     {
#       "score": 0.849495,
#       "label": "/technology and computing/operating systems"
#     },
#     {
#       "score": 0.832325,
#       "label": "/technology and computing/hardware/computer"
#     }
#   ]
# }

# %%
# Concepts Features

from ibm_watson.natural_language_understanding_v1 import Features, ConceptsOptions
 
response = natural_language_understanding.analyze(
    url='www.ibm.com',
    features=Features(concepts=ConceptsOptions(limit=3))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 982,
#     "features": 1
#   },
#   "retrieved_url": "https://www.ibm.com/uk-en",
#   "language": "en",
#   "concepts": [
#     {
#       "text": "United Kingdom",
#       "relevance": 0.933445,
#       "dbpedia_resource": "http://dbpedia.org/resource/United_Kingdom"
#     },
#     {
#       "text": "A New Era",
#       "relevance": 0.6435,
#       "dbpedia_resource": "http://dbpedia.org/resource/A_New_Era"
#     },
#     {
#       "text": "Northern Ireland",
#       "relevance": 0.642861,
#       "dbpedia_resource": "http://dbpedia.org/resource/Northern_Ireland"
#     }
#   ]
# }

# %%
# Emotions Features
from ibm_watson.natural_language_understanding_v1 import Features, EmotionOptions

response = natural_language_understanding.analyze(
    html="<html><head><title>Fruits</title></head><body><h1>Apples and Oranges</h1><p>I love apples! I don't like oranges.</p></body></html>",
    features=Features(emotion=EmotionOptions(targets=['apples','oranges']))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 37,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "targets": [
#       {
#         "text": "apples",
#         "emotion": {
#           "sadness": 0.028574,
#           "joy": 0.859042,
#           "fear": 0.02752,
#           "disgust": 0.017519,
#           "anger": 0.012855
#         }
#       },
#       {
#         "text": "oranges",
#         "emotion": {
#           "sadness": 0.514253,
#           "joy": 0.078317,
#           "fear": 0.074223,
#           "disgust": 0.058103,
#           "anger": 0.126859
#         }
#       }
#     ],
#     "document": {
#       "emotion": {
#         "sadness": 0.32665,
#         "joy": 0.563273,
#         "fear": 0.033387,
#         "disgust": 0.022637,
#         "anger": 0.041796
#       }
#     }
#   }
# }

# %%
# Entities Features 
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions

response = natural_language_understanding.analyze(
    url='www.mitwpu.edu.in',
    features=Features(entities=EntitiesOptions(sentiment=True,limit=1))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 17529,
#     "features": 1
#   },
#   "retrieved_url": "https://mitwpu.edu.in/",
#   "language": "en",
#   "entities": [
#     {
#       "type": "Organization",
#       "text": "MIT",
#       "sentiment": {
#         "score": 0.691044,
#         "label": "positive"
#       },
#       "relevance": 0.954206,
#       "disambiguation": {
#         "subtype": [
#           "Location",
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "Madras_Institute_of_Technology",
#         "dbpedia_resource": "http://dbpedia.org/resource/Madras_Institute_of_Technology"
#       },
#       "count": 20,
#       "confidence": 1.0
#     }
#   ]
# }

# %%
# Keywprds Features
from ibm_watson.natural_language_understanding_v1 import Features, KeywordsOptions

response = natural_language_understanding.analyze(
    url='www.ibm.com',
    features=Features(keywords=KeywordsOptions(sentiment=True,emotion=True,limit=2))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 1058,
#     "features": 1
#   },
#   "retrieved_url": "https://www.ibm.com/uk-en",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "latest news",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.670644,
#       "emotion": {
#         "sadness": 0.196169,
#         "joy": 0.049875,
#         "fear": 0.272843,
#         "disgust": 0.028455,
#         "anger": 0.066219
#       },
#       "count": 2
#     },
#     {
#       "text": "IBM's partnership",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.650901,
#       "emotion": {
#         "sadness": 0.057808,
#         "joy": 0.495425,
#         "fear": 0.004277,
#         "disgust": 0.006369,
#         "anger": 0.077146
#       },
#       "count": 1
#     }
#   ]
# }

# %%
#Metadata Feature
from ibm_watson.natural_language_understanding_v1 import Features, MetadataOptions

response = natural_language_understanding.analyze(
    url='www.ibm.com',
    features=Features(metadata=MetadataOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 1058,
#     "features": 1
#   },
#   "retrieved_url": "https://www.ibm.com/uk-en",
#   "metadata": {
#     "title": "IBM - United Kingdom",
#     "publication_date": "2019-06-25T00:00:00",
#     "image": "https://1.www.s81c.com/common/images/ibm-leadspace-1200x627.jpg",
#     "feeds": [],
#     "authors": []
#   },
#   "language": "en"
# }

# %%
# Relations Features 
from ibm_watson.natural_language_understanding_v1 import Features, RelationsOptions

response = natural_language_understanding.analyze(
    text='Leonardo DiCaprio won Best Actor in a Leading Role for his performance.',
    features=Features(relations=RelationsOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 71,
#     "features": 1
#   },
#   "relations": [
#     {
#       "type": "awardedTo",
#       "sentence": "Leonardo DiCaprio won Best Actor in a Leading Role for his performance.",
#       "score": 0.680715,
#       "arguments": [
#         {
#           "text": "Best Actor",
#           "location": [
#             22,
#             32
#           ],
#           "entities": [
#             {
#               "type": "EntertainmentAward",
#               "text": "Best Actor"
#             }
#           ]
#         },
#         {
#           "text": "Leonardo DiCaprio",
#           "location": [
#             0,
#             17
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Leonardo DiCaprio"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "language": "en"
# }

# %%
# Semantic Analysis
from ibm_watson.natural_language_understanding_v1 import Features, SemanticRolesOptions

response = natural_language_understanding.analyze(
    text='IBM has one of the largest workforces in the world',
    features=Features(semantic_roles=SemanticRolesOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 50,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "IBM"
#       },
#       "sentence": "IBM has one of the largest workforces in the world",
#       "object": {
#         "text": "one of the largest workforces in the world"
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "has",
#         "normalized": "have"
#       }
#     }
#   ],
#   "language": "en"
# }

# %%
# Sentiment Analysis
from ibm_watson.natural_language_understanding_v1 import Features, SentimentOptions

response = natural_language_understanding.analyze(
    url='www.ibm.com/in-en',
    features=Features(sentiment=SentimentOptions(targets=['AI']))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 940,
#     "features": 1
#   },
#   "sentiment": {
#     "targets": [
#       {
#         "text": "AI",
#         "score": 0,
#         "label": "neutral"
#       }
#     ],
#     "document": {
#       "score": 0.844309,
#       "label": "positive"
#     }
#   },
#   "retrieved_url": "https://www.ibm.com/in-en",
#   "language": "en"
# }

# %%
# Syntax Analysis
from ibm_watson.natural_language_understanding_v1 import Features, SyntaxOptions, SyntaxOptionsTokens

response = natural_language_understanding.analyze(
    text='With great power comes great responsibility',
    features=Features(
      syntax=SyntaxOptions(
        sentences=True,
        tokens=SyntaxOptionsTokens(
          lemma=True,
          part_of_speech=True,
        )))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 43,
#     "features": 1
#   },
#   "syntax": {
#     "tokens": [
#       {
#         "text": "With",
#         "part_of_speech": "ADP",
#         "location": [
#           0,
#           4
#         ],
#         "lemma": "with"
#       },
#       {
#         "text": "great",
#         "part_of_speech": "ADJ",
#         "location": [
#           5,
#           10
#         ],
#         "lemma": "great"
#       },
#       {
#         "text": "power",
#         "part_of_speech": "NOUN",
#         "location": [
#           11,
#           16
#         ],
#         "lemma": "power"
#       },
#       {
#         "text": "comes",
#         "part_of_speech": "VERB",
#         "location": [
#           17,
#           22
#         ],
#         "lemma": "come"
#       },
#       {
#         "text": "great",
#         "part_of_speech": "ADJ",
#         "location": [
#           23,
#           28
#         ],
#         "lemma": "great"
#       },
#       {
#         "text": "responsibility",
#         "part_of_speech": "NOUN",
#         "location": [
#           29,
#           43
#         ],
#         "lemma": "responsibility"
#       }
#     ],
#     "sentences": [
#       {
#         "text": "With great power comes great responsibility",
#         "location": [
#           0,
#           43
#         ]
#       }
#     ]
#   },
#   "language": "en"
# }
